# %% [markdown]
# # Entra Agent ID Sidecar Weather Agent
#
# This notebook mirrors the weather agent flow in langgraph_test.ipynb, but retrieves Agent Identity tokens via the Microsoft Entra sidecar for each tool call.
#
# **What you will do:**
# - Configure and run the sidecar container
# - Request Agent Identity tokens via sidecar
# - Run the mock weather agent (single-shot + streaming)

# %% [markdown]
# ## Sidecar setup (one-time)
#
# Follow the SIDECAR-GUIDE.md steps in the 3P-Agent-ID-Demo repo.
#
# ### 1) Configure the sidecar .env
# ```powershell
# cd sidecar
# Copy-Item .env.example .env
# # Edit .env with values from Start-EntraAgentIDWorkflow:
# # TENANT_ID=<your-tenant-id>
# # BLUEPRINT_APP_ID=<blueprint-app-id>
# # AGENT_CLIENT_ID=<agent-app-id>
# # BLUEPRINT_CLIENT_SECRET=<blueprint-secret>
# ```
#
# ### 2) Start the sidecar
# ```powershell
# docker-compose up -d
# Invoke-RestMethod -Uri "http://localhost:5001/healthz"  # Expect: Healthy
# ```

# %%
# Optional: install dependencies
#%pip install -q langchain-openai langchain-core python-dotenv requests
import asyncio
import os
from random import randint
from typing import Annotated
import requests
from dotenv import load_dotenv
from pydantic import Field

from langchain_core.tools import tool
from langchain_openai import AzureChatOpenAI
from langchain.agents import create_agent

load_dotenv()

REQUIRED_ENV = [
    "ENTRA_AGENT_APP_ID",
    "AZURE_OPENAI_ENDPOINT",
    "AZURE_OPENAI_API_KEY",
    "AZURE_OPENAI_API_VERSION",
    "AZURE_OPENAI_DEPLOYMENT",
]

missing = [key for key in REQUIRED_ENV if not os.getenv(key)]
if missing:
    raise EnvironmentError(f"Missing environment variables: {', '.join(missing)}")

AGENT_APP_ID = os.getenv("ENTRA_AGENT_APP_ID")
SIDECAR_BASE_URL = os.getenv("SIDECAR_BASE_URL", "http://localhost:5001")

# %%
def get_agent_token_from_sidecar():
    url = f"{SIDECAR_BASE_URL}/AuthorizationHeaderUnauthenticated/graph"
    resp = requests.get(url, params={"AgentIdentity": AGENT_APP_ID})
    resp.raise_for_status()
    return resp.json()["authorizationHeader"]  # Includes 'Bearer ' prefix

# %%
@tool
def get_weather(
    location: Annotated[str, Field(description="The location to get the weather for.")]
) -> str:
    """Get the weather for a given location (mock)."""
    _ = get_agent_token_from_sidecar()  # Sidecar retrieves Agent Identity token
    conditions = ["sunny", "cloudy", "rainy", "stormy"]
    return f"The weather in {location} is {conditions[randint(0, 3)]} with a high of {randint(10, 30)}°C."

# %%
llm = AzureChatOpenAI(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
    azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    temperature=0,
 )

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful weather agent.",
)

# %%
query = "What's the weather like in Seattle?"
result = agent.invoke({"messages": [("user", query)]})
result["messages"][-1].content
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 query = "What's the weather like in Seattle?"
# ----> 2 result = agent.invoke({"messages": [("user", query)]})
#       3 result["messages"][-1].content
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
#    3080     interrupt_before=interrupt_before,
#    3081     interrupt_after=interrupt_after,
#    3082     durability=durability,
#    3083     **kwargs,
#    3084 ):
#    3085     if stream_mode == "values":
#    3086         if len(chunk) == 2:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\main.py:2646, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2644 for task in loop.match_cached_writes():
#    2645     loop.output_writes(task.id, task.writes, cached=True)
# -> 2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    2649     get_waiter=get_waiter,
#    2650     schedule_task=loop.accept_push,
#    2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
#    2656 loop.after_tick()
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:813, in ToolNode._func(self, input, config, runtime)
#     811 input_types = [input_type] * len(tool_calls)
#     812 with get_executor_for_config(config) as executor:
# --> 813     outputs = list(
#     814         executor.map(self._run_one, tool_calls, input_types, tool_runtimes)
#     815     )
#     817 return self._combine_tool_outputs(outputs, input_type)
#
# File C:\Python313\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File C:\Python313\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File C:\Python313\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File C:\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\config.py:553, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     552 def _wrapped_fn(*args: Any) -> T:
# --> 553     return contexts.pop().run(fn, *args)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1024, in ToolNode._run_one(self, call, input_type, tool_runtime)
#    1020 config = tool_runtime.config
#    1022 if self._wrap_tool_call is None:
#    1023     # No wrapper - execute directly
# -> 1024     return self._execute_tool_sync(tool_request, input_type, config)
#    1026 # Define execute callable that can be called multiple times
#    1027 def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:973, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     970         raise
#     972     # Error is handled - create error ToolMessage
# --> 973     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#     974     return ToolMessage(
#     975         content=content,
#     976         name=call["name"],
#     977         tool_call_id=call["id"],
#     978         status="error",
#     979     )
#     981 # Process successful response
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:430, in _handle_tool_error(e, flag)
#     428     content = flag
#     429 elif callable(flag):
# --> 430     content = flag(e)  # type: ignore [assignment, call-arg]
#     431 else:
#     432     msg = (
#     433         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     434         f"or callable. Received: {flag}"
#     435     )
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:387, in _default_handle_tool_errors(e)
#     385 if isinstance(e, ToolInvocationError):
#     386     return e.message
# --> 387 raise e
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:930, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     928 try:
#     929     try:
# --> 930         response = tool.invoke(call_args, config)
#     931     except ValidationError as exc:
#     932         # Filter out errors for injected arguments
#     933         injected = self._injected_args.get(call["name"])
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:632, in BaseTool.invoke(self, input, config, **kwargs)
#     624 @override
#     625 def invoke(
#     626     self,
#    (...)    629     **kwargs: Any,
#     630 ) -> Any:
#     631     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 632     return self.run(tool_input, **kwargs)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:987, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     985 if error_to_raise:
#     986     run_manager.on_tool_error(error_to_raise)
# --> 987     raise error_to_raise
#     988 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     989 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:953, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     951     if config_param := _get_runnable_config_param(self._run):
#     952         tool_kwargs |= {config_param: config}
# --> 953     response = context.run(self._run, *tool_args, **tool_kwargs)
#     954 if self.response_format == "content_and_artifact":
#     955     msg = (
#     956         "Since response_format='content_and_artifact' "
#     957         "a two-tuple of the message content and raw tool output is "
#     958         f"expected. Instead, generated response is of type: "
#     959         f"{type(response)}."
#     960     )
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\structured.py:94, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      92     if config_param := _get_runnable_config_param(self.func):
#      93         kwargs[config_param] = config
# ---> 94     return self.func(*args, **kwargs)
#      95 msg = "StructuredTool does not support sync invocation."
#      96 raise NotImplementedError(msg)
#
# Cell In[3], line 6, in get_weather(location)
#       1 @tool
#       2 def get_weather(
#       3     location: Annotated[str, Field(description="The location to get the weather for.")]
#       4 ) -> str:
#       5     """Get the weather for a given location (mock)."""
# ----> 6     _ = get_agent_token_from_sidecar()  # Sidecar retrieves Agent Identity token
#       7     conditions = ["sunny", "cloudy", "rainy", "stormy"]
#       8     return f"The weather in {location} is {conditions[randint(0, 3)]} with a high of {randint(10, 30)}°C."
#
# Cell In[2], line 4, in get_agent_token_from_sidecar()
#       2 url = f"{SIDECAR_BASE_URL}/AuthorizationHeaderUnauthenticated/graph"
#       3 resp = requests.get(url, params={"AgentIdentity": AGENT_APP_ID})
# ----> 4 resp.raise_for_status()
#       5 return resp.json()["authorizationHeader"]
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: http://localhost:5001/AuthorizationHeaderUnauthenticated/graph?AgentIdentity=blah
# During task with name 'tools' and id 'c137fdba-7158-3d89-356f-45f422346e36'

# %%
async def stream_agent(query: str):
    print("Agent:", end=" ", flush=True)
    async for event in agent.astream_events(
        {"messages": [("user", query)]},
        version="v2",
    ):
        if event["event"] == "on_chat_model_stream":
            chunk = event["data"]["chunk"]
            if getattr(chunk, "content", None):
                print(chunk.content, end="", flush=True)
    print()

await stream_agent("What's the weather like in Portland?")
# Out:
# Agent: Sure! Let me check the weather for Portland.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      10                 print(chunk.content, end="", flush=True)
#      11     print()
# ---> 13 await stream_agent("What's the weather like in Portland?")
#
# Cell In[6], line 3, in stream_agent(query)
#       1 async def stream_agent(query: str):
#       2     print("Agent:", end=" ", flush=True)
# ----> 3     async for event in agent.astream_events(
#       4         {"messages": [("user", query)]},
#       5         version="v2",
#       6     ):
#       7         if event["event"] == "on_chat_model_stream":
#       8             chunk = event["data"]["chunk"]
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\base.py:1514, in Runnable.astream_events(self, input, config, version, include_names, include_types, include_tags, exclude_names, exclude_types, exclude_tags, **kwargs)
#    1511     raise NotImplementedError(msg)
#    1513 async with aclosing(event_stream):
# -> 1514     async for event in event_stream:
#    1515         yield event
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tracers\event_stream.py:1082, in _astream_events_implementation_v2(runnable, value, config, include_names, include_types, include_tags, exclude_names, exclude_types, exclude_tags, **kwargs)
#    1080 # Await it anyway, to run any cleanup code, and propagate any exceptions
#    1081 with contextlib.suppress(asyncio.CancelledError):
# -> 1082     await task
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tracers\event_stream.py:1037, in _astream_events_implementation_v2.<locals>.consume_astream()
#    1034 try:
#    1035     # if astream also calls tap_output_aiter this will be a no-op
#    1036     async with aclosing(runnable.astream(value, config, **kwargs)) as stream:
# -> 1037         async for _ in event_streamer.tap_output_aiter(run_id, stream):
#    1038             # All the content will be picked up
#    1039             pass
#    1040 finally:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tracers\event_stream.py:215, in _AstreamEventsCallbackHandler.tap_output_aiter(self, run_id, output)
#     213 yield cast("T", first)
#     214 # consume the rest of the output
# --> 215 async for chunk in output:
#     216     self._send(
#     217         {**event, "data": {"chunk": chunk}},
#     218         run_info["run_type"],
#     219     )
#     220     yield chunk
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\main.py:2974, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2972 for task in await loop.amatch_cached_writes():
#    2973     loop.output_writes(task.id, task.writes, cached=True)
# -> 2974 async for _ in runner.atick(
#    2975     [t for t in loop.tasks.values() if not t.writes],
#    2976     timeout=self.step_timeout,
#    2977     get_waiter=get_waiter,
#    2978     schedule_task=loop.aaccept_push,
#    2979 ):
#    2980     # emit output
#    2981     for o in _output(
#    2982         stream_mode,
#    2983         print_mode,
#    (...)   2986         asyncio.QueueEmpty,
#    2987     ):
#    2988         yield o
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     302 t = tasks[0]
#     303 try:
# --> 304     await arun_with_retry(
#     305         t,
#     306         retry_policy,
#     307         stream=self.use_astream,
#     308         configurable={
#     309             CONFIG_KEY_CALL: partial(
#     310                 _acall,
#     311                 weakref.ref(t),
#     312                 stream=self.use_astream,
#     313                 retry_policy=retry_policy,
#     314                 futures=weakref.ref(futures),
#     315                 schedule_task=schedule_task,
#     316                 submit=self.submit,
#     317                 loop=loop,
#     318             ),
#     319         },
#     320     )
#     321     self.commit(t, None)
#     322 except Exception as exc:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\pregel\_retry.py:133, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     131 # run the task
#     132 if stream:
# --> 133     async for _ in task.proc.astream(task.input, config):
#     134         pass
#     135     # if successful, end
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:839, in RunnableSeq.astream(self, input, config, **kwargs)
#     835             aiterator = h.tap_output_aiter(
#     836                 run_manager.run_id, aiterator
#     837             )
#     838 # consume into final output
# --> 839 output = await asyncio.create_task(
#     840     _consume_aiter(aiterator), context=context
#     841 )
#     842 # sequence doesn't emit output, yield to mark as generator
#     843 yield
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:904, in _consume_aiter(it)
#     902 output: Any = None
#     903 add_supported = False
# --> 904 async for chunk in it:
#     905     # collect final output
#     906     if add_supported:
#     907         try:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tracers\event_stream.py:192, in _AstreamEventsCallbackHandler.tap_output_aiter(self, run_id, output)
#     190 tap = self.is_tapped.setdefault(run_id, sentinel)
#     191 # wait for first chunk
# --> 192 first = await anext(output, sentinel)
#     193 if first is sentinel:
#     194     return
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\base.py:1587, in Runnable.atransform(self, input, config, **kwargs)
#    1584 final: Input
#    1585 got_first_val = False
# -> 1587 async for ichunk in input:
#    1588     # The default implementation of transform is to buffer input and
#    1589     # then call stream.
#    1590     # It'll attempt to gather all input into a single chunk using
#    1591     # the `+` operator.
#    1592     # If the input is not addable, then we'll assume that we can
#    1593     # only operate on the last chunk,
#    1594     # and we'll iterate until we get to the last chunk.
#    1595     if not got_first_val:
#    1596         final = ichunk
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\base.py:1587, in Runnable.atransform(self, input, config, **kwargs)
#    1584 final: Input
#    1585 got_first_val = False
# -> 1587 async for ichunk in input:
#    1588     # The default implementation of transform is to buffer input and
#    1589     # then call stream.
#    1590     # It'll attempt to gather all input into a single chunk using
#    1591     # the `+` operator.
#    1592     # If the input is not addable, then we'll assume that we can
#    1593     # only operate on the last chunk,
#    1594     # and we'll iterate until we get to the last chunk.
#    1595     if not got_first_val:
#    1596         final = ichunk
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\base.py:1168, in Runnable.astream(self, input, config, **kwargs)
#    1149 async def astream(
#    1150     self,
#    1151     input: Input,
#    1152     config: RunnableConfig | None = None,
#    1153     **kwargs: Any | None,
#    1154 ) -> AsyncIterator[Output]:
#    1155     """Default implementation of `astream`, which calls `ainvoke`.
#    1156
#    1157     Subclasses must override this method if they support streaming output.
#    (...)   1166
#    1167     """
# -> 1168     yield await self.ainvoke(input, config, **kwargs)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:473, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     471         await run_manager.on_chain_end(ret)
#     472 else:
# --> 473     ret = await self.afunc(*args, **kwargs)
#     474 if self.recurse and isinstance(ret, Runnable):
#     475     return await ret.ainvoke(input, config)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:846, in ToolNode._afunc(self, input, config, runtime)
#     844 for call, tool_runtime in zip(tool_calls, tool_runtimes, strict=False):
#     845     coros.append(self._arun_one(call, input_type, tool_runtime))  # type: ignore[arg-type]
# --> 846 outputs = await asyncio.gather(*coros)
#     848 return self._combine_tool_outputs(outputs, input_type)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1177, in ToolNode._arun_one(self, call, input_type, tool_runtime)
#    1173 config = tool_runtime.config
#    1175 if self._awrap_tool_call is None and self._wrap_tool_call is None:
#    1176     # No wrapper - execute directly
# -> 1177     return await self._execute_tool_async(tool_request, input_type, config)
#    1179 # Define async execute callable that can be called multiple times
#    1180 async def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1126, in ToolNode._execute_tool_async(self, request, input_type, config)
#    1123         raise
#    1125     # Error is handled - create error ToolMessage
# -> 1126     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#    1127     return ToolMessage(
#    1128         content=content,
#    1129         name=call["name"],
#    1130         tool_call_id=call["id"],
#    1131         status="error",
#    1132     )
#    1134 # Process successful response
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:430, in _handle_tool_error(e, flag)
#     428     content = flag
#     429 elif callable(flag):
# --> 430     content = flag(e)  # type: ignore [assignment, call-arg]
#     431 else:
#     432     msg = (
#     433         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     434         f"or callable. Received: {flag}"
#     435     )
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:387, in _default_handle_tool_errors(e)
#     385 if isinstance(e, ToolInvocationError):
#     386     return e.message
# --> 387 raise e
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1083, in ToolNode._execute_tool_async(self, request, input_type, config)
#    1081 try:
#    1082     try:
# -> 1083         response = await tool.ainvoke(call_args, config)
#    1084     except ValidationError as exc:
#    1085         # Filter out errors for injected arguments
#    1086         injected = self._injected_args.get(call["name"])
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\structured.py:65, in StructuredTool.ainvoke(self, input, config, **kwargs)
#      56 @override
#      57 async def ainvoke(
#      58     self,
#    (...)     61     **kwargs: Any,
#      62 ) -> Any:
#      63     if not self.coroutine:
#      64         # If the tool does not implement async, fall back to default implementation
# ---> 65         return await run_in_executor(config, self.invoke, input, config, **kwargs)
#      67     return await super().ainvoke(input, config, **kwargs)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\config.py:610, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     606         raise RuntimeError from exc
#     608 if executor_or_config is None or isinstance(executor_or_config, dict):
#     609     # Use default executor with context copied from current context
# --> 610     return await asyncio.get_running_loop().run_in_executor(
#     611         None,
#     612         cast("Callable[..., T]", partial(copy_context().run, wrapper)),
#     613     )
#     615 return await asyncio.get_running_loop().run_in_executor(executor_or_config, wrapper)
#
# File C:\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\runnables\config.py:601, in run_in_executor.<locals>.wrapper()
#     599 def wrapper() -> T:
#     600     try:
# --> 601         return func(*args, **kwargs)
#     602     except StopIteration as exc:
#     603         # StopIteration can't be set on an asyncio.Future
#     604         # it raises a TypeError and leaves the Future pending forever
#     605         # so we need to convert it to a RuntimeError
#     606         raise RuntimeError from exc
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:632, in BaseTool.invoke(self, input, config, **kwargs)
#     624 @override
#     625 def invoke(
#     626     self,
#    (...)    629     **kwargs: Any,
#     630 ) -> Any:
#     631     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 632     return self.run(tool_input, **kwargs)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:987, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     985 if error_to_raise:
#     986     run_manager.on_tool_error(error_to_raise)
# --> 987     raise error_to_raise
#     988 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     989 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:953, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     951     if config_param := _get_runnable_config_param(self._run):
#     952         tool_kwargs |= {config_param: config}
# --> 953     response = context.run(self._run, *tool_args, **tool_kwargs)
#     954 if self.response_format == "content_and_artifact":
#     955     msg = (
#     956         "Since response_format='content_and_artifact' "
#     957         "a two-tuple of the message content and raw tool output is "
#     958         f"expected. Instead, generated response is of type: "
#     959         f"{type(response)}."
#     960     )
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\langchain_core\tools\structured.py:94, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      92     if config_param := _get_runnable_config_param(self.func):
#      93         kwargs[config_param] = config
# ---> 94     return self.func(*args, **kwargs)
#      95 msg = "StructuredTool does not support sync invocation."
#      96 raise NotImplementedError(msg)
#
# Cell In[3], line 6, in get_weather(location)
#       1 @tool
#       2 def get_weather(
#       3     location: Annotated[str, Field(description="The location to get the weather for.")]
#       4 ) -> str:
#       5     """Get the weather for a given location (mock)."""
# ----> 6     _ = get_agent_token_from_sidecar()  # Sidecar retrieves Agent Identity token
#       7     conditions = ["sunny", "cloudy", "rainy", "stormy"]
#       8     return f"The weather in {location} is {conditions[randint(0, 3)]} with a high of {randint(10, 30)}°C."
#
# Cell In[2], line 4, in get_agent_token_from_sidecar()
#       2 url = f"{SIDECAR_BASE_URL}/AuthorizationHeaderUnauthenticated/graph"
#       3 resp = requests.get(url, params={"AgentIdentity": AGENT_APP_ID})
# ----> 4 resp.raise_for_status()
#       5 return resp.json()["authorizationHeader"]
#
# File c:\Users\armoshar\OneDrive - Microsoft\DEMOS\OpenAI\agent-framework\00-Langgraph\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: http://localhost:5001/AuthorizationHeaderUnauthenticated/graph?AgentIdentity=blah
# During task with name 'tools' and id '16a9494f-35ac-dc4d-87cf-7afd873c495b'

# %% [markdown]
# ## Notes
# - If the sidecar returns 403, verify the Agent Identity has required permissions and wait for propagation.
# - If you see 404, confirm the sidecar is healthy at `http://localhost:5001/healthz`.
# - This uses the token-only pattern (`/AuthorizationHeaderUnauthenticated`) so your app controls HTTP calls.
